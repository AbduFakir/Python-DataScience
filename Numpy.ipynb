# %% [markdown]
# <a href="https://colab.research.google.com/github/AbduFakir/Python-DataScience/blob/main/Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
kohli_runs = np.array([45,72,33,61,88,54,40,76,92,58])
print(kohli_runs)
# Out:
# [45 72 33 61 88 54 40 76 92 58]

# %%
type(kohli_runs)
# Out:
# numpy.ndarray

# %%
kohli_runs.shape
# Out:
# (10,)

# %%
batters = np.array([[34,45,65],[23,56,68],[34,78,43]])
print(batters)
# Out:
# [[34 45 65]
#  [23 56 68]
#  [34 78 43]]

# %%
batters.shape
# Out:
# (3, 3)

# %%
batters.ndim
# Out:
# 2

# %%
batters.dtype
# Out:
# dtype('int64')

# %%
batters.size
# Out:
# 9

# %%
batters.nbytes
# Out:
# 72

# %%
kohli_runs[0]
# Out:
# np.int64(45)

# %%
kohli_runs[-3:]
# Out:
# array([76, 92, 58])

# %%
batters[1][2]
# Out:
# np.int64(68)

# %%
runs = np.array([10,20,30,40,50,60])
runs.reshape(3,2)
# Out:
# array([[10, 20],
#        [30, 40],
#        [50, 60]])

# %%
print(runs)
# Out:
# [10 20 30 40 50 60]

# %%
kohli_runs
# Out:
# array([45, 72, 33, 61, 88, 54, 40, 76, 92, 58])

# %%
kohli_runs + 10
# Out:
# array([ 55,  82,  43,  71,  98,  64,  50,  86, 102,  68])

# %%
kohli_runs * 2
# Out:
# array([ 90, 144,  66, 122, 176, 108,  80, 152, 184, 116])

# %%
np.sum(kohli_runs)
# Out:
# np.int64(619)

# %%
np.mean(kohli_runs)
# Out:
# np.float64(61.9)

# %%
np.max(kohli_runs)
# Out:
# np.int64(92)

# %%
np.min(kohli_runs)
# Out:
# np.int64(33)

# %%
np.median(kohli_runs)
# Out:
# np.float64(59.5)

# %%
np.std(kohli_runs)
# Out:
# np.float64(18.886238376129853)

# %%
kohli_runs > 50
# Out:
# array([False,  True, False,  True,  True,  True, False,  True,  True,
#         True])

# %%
kohli_runs[kohli_runs > 50]
# Out:
# array([72, 61, 88, 54, 76, 92, 58])

# %%
scores = np.array([[180,175,189],[165,200,210],[150,185,170]])
print(scores)
# Out:
# [[180 175 189]
#  [165 200 210]
#  [150 185 170]]

# %%
np.mean(scores, axis=1)
# Out:
# array([181.33333333, 191.66666667, 168.33333333])

# %%
np.mean(scores, axis=0)
# Out:
# array([165.        , 186.66666667, 189.66666667])
