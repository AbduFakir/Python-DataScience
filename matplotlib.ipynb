# %% [markdown]
# <a href="https://colab.research.google.com/github/AbduFakir/Python-DataScience/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/class_ipl_22-26_dataset.csv')
df.head()
# Out:
#          date  season    city                                          venue  \
# 0  26-03-2022    2022  Mumbai                       Wankhede Stadium, Mumbai
# 1  27-03-2022    2022  Mumbai                      Brabourne Stadium, Mumbai
# 2  27-03-2022    2022  Mumbai             Dr DY Patil Sports Academy, Mumbai
# 3  28-03-2022    2022  Mumbai                       Wankhede Stadium, Mumbai
# 4  29-03-2022    2022    Pune  Maharashtra Cricket Association Stadium, Pune
#
#                          team1                  team2            toss_winner  \
# 0          Chennai Super Kings  Kolkata Knight Riders  Kolkata Knight Riders
# 1               Mumbai Indians         Delhi Capitals         Delhi Capitals
# 2  Royal Challengers Bangalore           Punjab Kings           Punjab Kings
# 3         Lucknow Super Giants         Gujarat Titans         Gujarat Titans
# 4             Rajasthan Royals    Sunrisers Hyderabad    Sunrisers Hyderabad
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             367 non-null    object
#  1   season           367 non-null    int64
#  2   city             367 non-null    object
#  3   venue            367 non-null    object
#  4   team1            367 non-null    object
#  5   team2            367 non-null    object
#  6   toss_winner      367 non-null    object
#  7   toss_decision    367 non-null    object
#  8   team1_runs       367 non-null    int64
#  9   team1_wickets    367 non-null    int64
#  10  team2_runs       367 non-null    int64
#  11  team2_wickets    367 non-null    int64
#  12  winner           360 non-null    object
#  13  result_type      367 non-null    object
#  14  win_by_runs      367 non-null    int64
#  15  win_by_wickets   367 non-null    int64
#  16  player_of_match  362 non-null    object
# ...

# %%
df['team1_wickets'].max()
# Out:
# 10

# %%
print(df['team2_wickets'].idxmax())
# Out:
# 10

# %%
#Line plot

plt.plot(df['team1_runs'].tail(74))
plt.xlabel('Match Index')
plt.ylabel('Team1 Runs')
plt.title('Team1 runs trend (last 74 matches)')
plt.show()

# %%
#line plot

plt.plot(df['team2_runs'].tail(74),'g--',label='Team2 Runs')
plt.xlabel('Match Index')
plt.ylabel('Team2 Runs')
plt.title('Team2 runs trend (last 74 matches)')
plt.legend
plt.show()

# %%
# multiline plot

plt.figure(figsize=(12,6))
plt.plot(df['team1_runs'].tail(74),label='Team1 runs',color='purple')
plt.plot(df['team1_wickets'].tail(74),label='Team1 wickets',color='orange')
plt.xlabel('Runs')
plt.ylabel('wickets')
plt.title('Team Runs Vs Team Wickets')
plt.legend()
plt.grid(True)
plt.show()

# %%
#multiline plot

plt.figure(figsize=(12,6))
plt.plot(df['team1_runs'].tail(74),label='Team1 runs',color='green')
plt.plot(df['team2_runs'].tail(74),label='Team2 runs',color='maroon')
plt.xlabel('Match Index')
plt.ylabel('Runs')
plt.title('Team1 Runs Vs Team2 Runs Trend (Last 74 matches)')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Scatter Plot

match_indices = df.index[-74:]

plt.scatter(match_indices, df['team1_runs'].tail(74),c='blue' , label='Team1 runs')
plt.scatter(match_indices, df['team2_runs'].tail(74),c='red' , label='Team2 runs')
plt.xlabel('match index')
plt.ylabel('Runs')
plt.title('Team 1 and Team 2 Riuns per match (last 74 matches)')
plt.legend()
plt.show()

# %%
#Histogram

plt.hist(df['team2_wickets'].tail(74),bins=10)
plt.xlabel('Wickets')
plt.ylabel('Number of Matches')
plt.title('Distribution of Team 2 Wickets')
plt.show()

# %%
#Bar Chart

toss_decisions = df['toss_decision'].value_counts()

plt.figure(figsize=(8,6))
plt.bar(toss_decisions.index,toss_decisions.values,color=['skyblue','lightcoral'])
plt.xlabel('Toss Decision')
plt.ylabel('Number of Matches')
plt.title('Distribution of toss decisions')
plt.show()

# %%
toss_decisions.index
# Out:
# Index(['field', 'bat'], dtype='object', name='toss_decision')

# %%
toss_decisions.values
# Out:
# array([285,  82])

# %%
#Bar Chart

team_wins = df['winner'].value_counts()

plt.figure(figsize=(8,6))
plt.bar(team_wins.index,team_wins.values,color=['skyblue','lightcoral'])
plt.xlabel('Winning Teams')
plt.ylabel('Number of Matches')
plt.title('Distribution of Winning Teams')
plt.xticks(rotation=90)
plt.show()

# %%
#Boxplot

plt.boxplot(df['team2_runs'])
plt.ylabel('Team 2 Runs')
plt.title('Distribution of team 2 runs')
plt.show()

# %%
df['team2_runs'].describe()
# Out:
# count    367.000000
# mean     169.250681
# std       38.827661
# min        0.000000
# 25%      150.500000
# 50%      171.000000
# 75%      196.000000
# max      265.000000
# Name: team2_runs, dtype: float64

# %%
#piechart

result_type_counts = df['winner'].value_counts()

plt.figure(figsize=(8,8))
plt.pie(result_type_counts.values,labels=result_type_counts.index,pctdistance=1)
plt.title('Distribution of match result types')
plt.xticks(rotation=90)
plt.show()
